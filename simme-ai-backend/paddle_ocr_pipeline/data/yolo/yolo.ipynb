# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install ultralytics

# %%
# !rm -rf /content/regions
# !rm -rf /content/yolo_regions
# !unzip -oq "/content/drive/MyDrive/yolo_regions/regions.zip" -d /content
# !mv /content/regions /content/yolo_regions

# %%
# !ls /content/yolo_regions
# Out:
# curated_pages.json  dataset.yaml  images  labels  README_COLAB.md

# %%
# !cat /content/yolo_regions/dataset.yaml
# Out:
# path: /content/yolo_regions
# train: images/train
# val: images/val
#
# names:
#   0: metadata_block
#   1: customer_block
#   2: equipment_block
#   3: work_conditions_block
#   4: reference_block
#   5: results_table

# %%
from pathlib import Path

for split in ["train", "val"]:
    labels_dir = Path(f"/content/yolo_regions/labels/{split}")
    for txt_file in labels_dir.glob("*.txt"):
        text = txt_file.read_text(encoding="utf-8-sig")
        txt_file.write_text(text, encoding="utf-8")

# %%
# !rm -f /content/yolo_regions/labels/train.cache
# !rm -f /content/yolo_regions/labels/val.cache

# %%
# !head -n 5 "/content/yolo_regions/labels/train/CITC_021_CORK SUPPLY PORTUGAL__page_01.txt"
# Out:
# 2 0.5242389587389045 0.15606539139899614 0.9115338629500953 0.018007545161422608
# 0 0.3544853911472592 0.21308928441016778 0.46361268459903116 0.05602347383553706
# 1 0.3815889019392026 0.3321391663106841 0.5377907141348762 0.09003772580711314
# 3 0.5434967164068643 0.5562330616528324 0.8530473396622174 0.06002515053807549

# %%
from ultralytics import YOLO

model = YOLO("yolo11n.pt")
results = model.train(
    data="/content/yolo_regions/dataset.yaml",
    epochs=20,
    imgsz=1280,
    batch=4,
    project="/content/drive/MyDrive/yolo_runs",
    name="regions_v1_test"
)
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import files
files.download('/content/drive/MyDrive/yolo_runs/regions_v1_test-2/weights/best.pt')
